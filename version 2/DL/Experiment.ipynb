# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
data=load_iris()

# %%
X=data.data
y=data.target
y=np.where(y==0,1,1)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
perceptron=Perceptron()
perceptron.fit(X_train,y_train)
y_pred_train=perceptron.predict(X_train)
y_pred_test=perceptron.predict(X_test)
print("Train accuracy: ", accuracy_score(y_train,y_pred_train))
print("Test accuracy: ", accuracy_score(y_test,y_pred_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 perceptron=Perceptron()
# ----> 2 perceptron.fit(X_train,y_train)
#       3 y_pred_train=perceptron.predict(X_train)
#       4 y_pred_test=perceptron.predict(X_test)
#       5 print("Train accuracy: ", accuracy_score(y_train,y_pred_train))
#
# File ~/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages/sklearn/linear_model/_stochastic_gradient.py:933, in BaseSGDClassifier.fit(self, X, y, coef_init, intercept_init, sample_weight)
#     904 """Fit linear model with Stochastic Gradient Descent.
#     905
#     906 Parameters
#    (...)    929     Returns an instance of self.
#     930 """
#     931 self._more_validate_params()
# --> 933 return self._fit(
#     934     X,
#     935     y,
#     936     alpha=self.alpha,
#     937     loss=self.loss,
#     938     learning_rate=self.learning_rate,
#     939     coef_init=coef_init,
#     940     intercept_init=intercept_init,
#     941     sample_weight=sample_weight,
#     942 )
#
# File ~/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages/sklearn/linear_model/_stochastic_gradient.py:715, in BaseSGDClassifier._fit(self, X, y, alpha, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     712 # Clear iteration count for multiple call to fit.
#     713 self.t_ = 1.0
# --> 715 self._partial_fit(
#     716     X,
#     717     y,
#     718     alpha,
#     719     loss,
#     720     learning_rate,
#     721     self.max_iter,
#     722     classes,
#     723     sample_weight,
#     724     coef_init,
#     725     intercept_init,
#     726 )
#     728 if (
#     729     self.tol is not None
#     730     and self.tol > -np.inf
#     731     and self.n_iter_ == self.max_iter
#     732 ):
#     733     warnings.warn(
#     734         (
#     735             "Maximum number of iteration reached before "
#    (...)    739         ConvergenceWarning,
#     740     )
#
# File ~/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages/sklearn/linear_model/_stochastic_gradient.py:670, in BaseSGDClassifier._partial_fit(self, X, y, alpha, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     661     self._fit_binary(
#     662         X,
#     663         y,
#    (...)    667         max_iter=max_iter,
#     668     )
#     669 else:
# --> 670     raise ValueError(
#     671         "The number of classes has to be greater than one; got %d class"
#     672         % n_classes
#     673     )
#     675 return self
#
# ValueError: The number of classes has to be greater than one; got 1 class
